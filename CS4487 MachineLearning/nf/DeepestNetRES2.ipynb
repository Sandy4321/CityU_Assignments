# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization,Activation
from keras.preprocessing.image import ImageDataGenerator
from keras import backend
from keras.optimizers import RMSprop, Adam
from keras import regularizers
from keras.callbacks import LearningRateScheduler
from keras.models import load_model

from keras.utils import to_categorical

def unpickle(file, train=True):
    import pickle
    with open('./cifar-10-batches-py/'+(('data_batch_'+str(file)) if train else 'test_batch'), 'rb') as fo:
        dict_d = pickle.load(fo,encoding='latin-1')
    return np.reshape(dict_d['data'],(10000,3,32,32)).transpose(0, 2, 3, 1), dict_d['labels']
# def normalization(x):
#     return x/255

training_set = []
training_label = []
for i in range(1,6):
    x,y = unpickle(i)
    training_set.extend(x) 
    training_label.extend(y)

test_data,test_label = unpickle(5,train=False)

test_data_norm = np.array(test_data) / 255
test_label_one_hot_encoded = to_categorical(test_label)

training_set_norm = np.array(training_set) / 255
training_label_one_hot_encode = to_categorical(training_label)

batch_size = 128
epochs = 10
IMG_HEIGHT = 32
IMG_WIDTH = 32

labels_name = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck"
]

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 800
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = ((np.array(training_set),np.array(training_label)),(np.array(test_data),np.array(test_label)))

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 700:
        lr *= 0.5e-7
    elif epoch > 600:
        lr *= 0.5e-6
    elif epoch > 500:
        lr *= 0.5e-5
    elif epoch > 300:
        lr *= 0.5e-4
    elif epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
#     model = load_model('./saved_models/cifar10_ResNet29v2_model.084.h5')
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format="channels_last",
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        steps_per_epoch =training_set_norm.shape[0] // 32,
#                         validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
#                         initial_epoch=84,
                        callbacks=callbacks)
#     model.save('./modelRES2.h5')
    

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000,)
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 16)   64          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 16)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 16)   272         activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 16)   64          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 16)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 16)   2320        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 16)   64          conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 16)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 64)   1088        activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 64)   1088        activation_59[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 64)   0           conv2d_67[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 64)   256         add_19[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 64)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 16)   1040        activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 16)   64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 16)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 16)   2320        activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 16)   64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 16)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 64)   1088        activation_62[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           add_19[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 64)   256         add_20[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 64)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 16)   1040        activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 16)   64          conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 16)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 16)   2320        activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 16)   64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 16)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 64)   1088        activation_65[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 64)   0           add_20[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 64)   256         add_21[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 32, 32, 64)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 64)   4160        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 64)   256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 64)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 64)   36928       activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 16, 16, 64)   256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 16, 64)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 16, 128)  8320        add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 128)  8320        activation_68[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 128)  0           conv2d_77[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 128)  512         add_22[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 128)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 64)   8256        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 64)   256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 16, 64)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 64)   36928       activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 64)   256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 16, 16, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 128)  8320        activation_71[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 128)  0           add_22[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 128)  512         add_23[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 16, 16, 128)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 64)   8256        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 64)   256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 16, 16, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 64)   36928       activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 64)   256         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 16, 64)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 128)  8320        activation_74[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 128)  0           add_23[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 128)  512         add_24[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 16, 128)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 128)    16512       activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 128)    512         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 128)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 128)    147584      activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 128)    512         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 128)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 256)    33024       add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 256)    33024       activation_77[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 256)    0           conv2d_87[0][0]
#                                                                  conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 256)    1024        add_25[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 256)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 128)    32896       activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 128)    512         conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 128)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 128)    147584      activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 128)    512         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 128)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 256)    33024       activation_80[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 256)    0           add_25[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 256)    1024        add_26[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 256)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 128)    32896       activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 128)    512         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 128)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 128)    147584      activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 128)    512         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 128)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 256)    33024       activation_83[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 256)    0           add_26[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 256)    1024        add_27[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 256)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 256)    0           activation_84[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 256)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           2570        flatten_3[0][0]
# ==================================================================================================
# Total params: 849,002
# Trainable params: 843,786
# Non-trainable params: 5,216
# __________________________________________________________________________________________________
# ResNet29v2
# Using real-time data augmentation.
# Epoch 1/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 60s 38ms/step - loss: 1.8340 - acc: 0.4958
# Epoch 2/800
# Learning rate:  0.001
#    5/1562 [..............................] - ETA: 58s - loss: 1.4287 - acc: 0.6562
# C:\Anaconda3\lib\site-packages\keras\callbacks.py:432: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# C:\Anaconda3\lib\site-packages\keras\callbacks.py:1043: RuntimeWarning: Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 1562/1562 [==============================] - 52s 33ms/step - loss: 1.3589 - acc: 0.6286
# Epoch 3/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 1.1765 - acc: 0.6827
# Epoch 4/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 1.0599 - acc: 0.7241
# Epoch 5/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.9888 - acc: 0.7469 0s - loss: 0.9887
# Epoch 6/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.9315 - acc: 0.7661
# Epoch 7/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.8922 - acc: 0.7783
# Epoch 8/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.8548 - acc: 0.7906
# Epoch 9/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.8335 - acc: 0.7986
# Epoch 10/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.8051 - acc: 0.8060
# Epoch 11/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.7868 - acc: 0.8120 3s - loss: 0.78
# Epoch 12/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.7643 - acc: 0.8196
# Epoch 13/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.7509 - acc: 0.8221
# Epoch 14/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.7348 - acc: 0.8277 0s - loss: 0.7355 -
# Epoch 15/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.7158 - acc: 0.8334
# Epoch 16/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.7093 - acc: 0.8365
# Epoch 17/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6942 - acc: 0.8414
# Epoch 18/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6861 - acc: 0.8419
# Epoch 19/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6802 - acc: 0.8442 2s - loss: 0.6809 - acc: - ETA: 1s
# Epoch 20/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6696 - acc: 0.8466
# Epoch 21/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6653 - acc: 0.8500
# Epoch 22/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6573 - acc: 0.8515
# Epoch 23/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6442 - acc: 0.8562
# Epoch 24/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6369 - acc: 0.8580
# Epoch 25/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6339 - acc: 0.8585
# Epoch 26/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6295 - acc: 0.8605
# Epoch 27/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6266 - acc: 0.8612
# Epoch 28/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6192 - acc: 0.8622
# Epoch 29/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6117 - acc: 0.8655
# Epoch 30/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6096 - acc: 0.8671
# Epoch 31/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6028 - acc: 0.8681
# Epoch 32/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.6054 - acc: 0.8676
# Epoch 33/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5973 - acc: 0.8693
# Epoch 34/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5931 - acc: 0.8722
# Epoch 35/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5866 - acc: 0.8732
# Epoch 36/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5877 - acc: 0.8723
# Epoch 37/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5829 - acc: 0.8743
# Epoch 38/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5802 - acc: 0.8738
# Epoch 39/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5729 - acc: 0.8766
# Epoch 40/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5794 - acc: 0.8742
# Epoch 41/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5708 - acc: 0.8766
# Epoch 42/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5675 - acc: 0.8789 2s - lo - ETA: 1s - loss: 0.5
# Epoch 43/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5668 - acc: 0.8780
# Epoch 44/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5617 - acc: 0.8806
# Epoch 45/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5585 - acc: 0.8810
# Epoch 46/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5556 - acc: 0.8814
# Epoch 47/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5527 - acc: 0.8825
# Epoch 48/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5526 - acc: 0.8850
# Epoch 49/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5541 - acc: 0.8826
# Epoch 50/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5484 - acc: 0.8851
# Epoch 51/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5475 - acc: 0.8833
# Epoch 52/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5454 - acc: 0.8848
# Epoch 53/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5452 - acc: 0.8854 1s - loss
# Epoch 54/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5425 - acc: 0.8854
# Epoch 55/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5403 - acc: 0.8865
# Epoch 56/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5360 - acc: 0.8870
# Epoch 57/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5403 - acc: 0.8867
# Epoch 58/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5296 - acc: 0.8891
# Epoch 59/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5351 - acc: 0.8866 3 - ETA: 1s - loss: 0.5
# Epoch 60/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5299 - acc: 0.8887
# Epoch 61/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5334 - acc: 0.8878
# Epoch 62/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.5269 - acc: 0.8895
# Epoch 63/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.5245 - acc: 0.8901 0s - loss: 0.5246 - ac
# Epoch 64/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5246 - acc: 0.8919
# Epoch 65/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5185 - acc: 0.8924 0s - loss: 0.5189 - acc:
# Epoch 66/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5233 - acc: 0.8903
# Epoch 67/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5153 - acc: 0.8925 4s - loss: - ETA: 3s - loss: 0.5155
# Epoch 68/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5177 - acc: 0.8929
# Epoch 69/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5189 - acc: 0.8921
# Epoch 70/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.5133 - acc: 0.8941
# Epoch 71/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 53s 34ms/step - loss: 0.5120 - acc: 0.8953
# Epoch 72/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.5105 - acc: 0.8950
# Epoch 73/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5077 - acc: 0.8949
# Epoch 74/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.5085 - acc: 0.8957
# Epoch 75/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5101 - acc: 0.8942
# Epoch 76/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5021 - acc: 0.8975
# Epoch 77/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5069 - acc: 0.8955
# Epoch 78/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5035 - acc: 0.8952
# Epoch 79/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.5028 - acc: 0.8971
# Epoch 80/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.5042 - acc: 0.8944
# Epoch 81/800
# Learning rate:  0.001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.4997 - acc: 0.8962
# Epoch 82/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.4153 - acc: 0.9268
# Epoch 83/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.3792 - acc: 0.9388
# Epoch 84/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3677 - acc: 0.9415
# Epoch 85/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3542 - acc: 0.9439
# Epoch 86/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3479 - acc: 0.9454
# Epoch 87/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3375 - acc: 0.9484 4s - loss
# Epoch 88/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 53s 34ms/step - loss: 0.3295 - acc: 0.9499
# Epoch 89/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.3226 - acc: 0.9503
# Epoch 90/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3176 - acc: 0.9520
# Epoch 91/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3138 - acc: 0.9518
# Epoch 92/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3066 - acc: 0.9548
# Epoch 93/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.3012 - acc: 0.9550
# Epoch 94/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.2952 - acc: 0.9571
# Epoch 95/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2926 - acc: 0.9576
# Epoch 96/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2865 - acc: 0.9580
# Epoch 97/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 53s 34ms/step - loss: 0.2839 - acc: 0.9583
# Epoch 98/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2775 - acc: 0.9600
# Epoch 99/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2762 - acc: 0.9592
# Epoch 100/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 53s 34ms/step - loss: 0.2713 - acc: 0.9610
# Epoch 101/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.2696 - acc: 0.9610
# Epoch 102/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2648 - acc: 0.9622
# Epoch 103/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 53s 34ms/step - loss: 0.2615 - acc: 0.9632
# Epoch 104/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2596 - acc: 0.9620
# Epoch 105/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2567 - acc: 0.9634
# Epoch 106/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2540 - acc: 0.9635
# Epoch 107/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2515 - acc: 0.9648
# Epoch 108/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 53s 34ms/step - loss: 0.2460 - acc: 0.9661
# Epoch 109/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2486 - acc: 0.9644
# Epoch 110/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2432 - acc: 0.9664
# Epoch 111/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2403 - acc: 0.9663
# Epoch 112/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2378 - acc: 0.9678 1s - loss: 0.23
# Epoch 113/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2336 - acc: 0.9684
# Epoch 114/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2339 - acc: 0.9678
# Epoch 115/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.2313 - acc: 0.9687
# Epoch 116/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2274 - acc: 0.9696
# Epoch 117/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2254 - acc: 0.9695
# Epoch 118/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2246 - acc: 0.9696
# Epoch 119/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2244 - acc: 0.9692
# Epoch 120/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2206 - acc: 0.9703
# Epoch 121/800
# Learning rate:  0.0001
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2192 - acc: 0.9705
# Epoch 122/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2107 - acc: 0.9727
# Epoch 123/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2059 - acc: 0.9747
# Epoch 124/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2065 - acc: 0.9752
# Epoch 125/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2026 - acc: 0.9763
# Epoch 126/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2048 - acc: 0.9760
# Epoch 127/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2017 - acc: 0.9762
# Epoch 128/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.2017 - acc: 0.9773
# Epoch 129/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1994 - acc: 0.9772
# Epoch 130/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1987 - acc: 0.9780
# Epoch 131/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1984 - acc: 0.9780
# Epoch 132/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1975 - acc: 0.9776
# Epoch 133/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1982 - acc: 0.9783
# Epoch 134/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1974 - acc: 0.9779
# Epoch 135/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1972 - acc: 0.9792
# Epoch 136/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1995 - acc: 0.9771
# Epoch 137/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1966 - acc: 0.9787
# Epoch 138/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1957 - acc: 0.9791
# Epoch 139/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 34ms/step - loss: 0.1948 - acc: 0.9785
# Epoch 140/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1939 - acc: 0.9788
# Epoch 141/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 52s 33ms/step - loss: 0.1937 - acc: 0.9789
# Epoch 142/800
# Learning rate:  1e-05
# 1562/1562 [==============================] - 51s 33ms/step - loss: 0.1952 - acc: 0.9785 3s - loss
# Epoch 143/800
# Learning rate:  1e-05
#  689/1562 [============>.................] - ETA: 29s - loss: 0.1932 - acc: 0.9794
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b9e836a4d7fc> in <module>
#     424                         epochs=epochs, verbose=1, workers=4,
#     425 #                         initial_epoch=84,
# --> 426                         callbacks=callbacks)
#     427 #     model.save('./modelRES2.h5')
#     428
#
# C:\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# C:\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     211                 outs = model.train_on_batch(x, y,
#     212                                             sample_weight=sample_weight,
# --> 213                                             class_weight=class_weight)
#     214
#     215                 outs = to_list(outs)
#
# C:\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1213             ins = x + y + sample_weights
#    1214         self._make_train_function()
# -> 1215         outputs = self.train_function(ins)
#    1216         return unpack_singleton(outputs)
#    1217
#
# C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model.save('./modelRES2FULL.h5')

# %%
import pickle
pickle.dump(history.history,open('./historyRES22222222','wb'))

# %%
accuracy2 = model.evaluate(x=test_data_norm,y=test_label_one_hot_encoded,batch_size=32)
print("Accuracy: ",accuracy2[1])

# %%
from matplotlib import pyplot
def summarize_diagnostics(xx):
	# plot loss
	pyplot.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
	ax1=pyplot.subplot(211)
	pyplot.title('Cross Entropy Loss')
	pyplot.plot(xx['loss'], color='blue', label='train')
	pyplot.plot(xx['val_loss'], color='orange', label='test')
	pyplot.plot(xx['val_loss'], color='orange', label='test')
	ax2 = ax1.twinx()
    
# 	ax2.plot(xx['learning_rate'],color='#00000055',label='lr')
# 	# plot accuracy
	ax3=pyplot.subplot(212)
	pyplot.title('Classification Accuracy')
	pyplot.plot(xx['acc'], color='blue', label='train')
	pyplot.plot(xx['val_acc'], color='orange', label='test')
	ax4 = ax3.twinx()
# 	ax4.plot(-xx['learning_rate'],color='#00000055',label='lr')
	# save plot to file

# %%
summarize_diagnostics(history.history)

# %%
pp = np.load('./test_data/y_test.npy')
pp_norm = pp/255
test_res = []
for i in model.predict(pp_norm):
    test_res.append(np.argmax(i))
# summarize_diagnostics(history41)
# summarize_diagnostics(history42)
# summarize_diagnostics(history43)

df = pd.DataFrame({'Category':test_res})
df['Index'] = df.index
df = df[['Index','Category']]
df.to_csv('./test_resRES2_3.csv',index=False)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    
    if epoch > 700:
        lr *= 0.5e-7
    elif epoch > 600:
        lr *= 0.5e-6
    elif epoch > 500:
        lr *= 0.5e-5
    elif epoch > 300:
        lr *= 0.5e-4
    elif epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        steps_per_epoch =training_set_norm.shape[0] // 32,
                        validation_data=(x_test, y_test),
                        epochs=epochs+600, verbose=1, workers=4, initial_epoch=200
                        callbacks=callbacks)
pickle.dump(history.history,open('historyRES2_2','wb'))

# %%
pp = np.load('./test_data/y_test.npy')
pp_norm = pp/255
test_res = []
for i in model.predict(pp_norm):
    test_res.append(np.argmax(i))
# summarize_diagnostics(history41)
# summarize_diagnostics(history42)
# summarize_diagnostics(history43)

df = pd.DataFrame({'Category':test_res})
df['Index'] = df.index
df = df[['Index','Category']]
df.to_csv('./test_resRES2_3.csv',index=False)
