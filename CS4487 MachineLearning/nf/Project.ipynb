# %%
import pickle
d = pickle.load(open('C:/temp/test_res','rb'))

# %%
d
# Out:
# [1,
#  0,
#  8,
#  8,
#  1,
#  8,
#  7,
#  0,
#  0,
#  1,
#  0,
#  9,
#  1,
#  2,
#  3,
#  0,
#  8,
#  8,
#  0,
#  9,
#  9,
#  0,
#  0,
#  0,
#  0,
#  0,
#  8,
#  6,
#  1,
#  9,
#  8,
#  8,
#  8,
#  8,
#  0,
#  0,
#  8,
#  0,
#  0,
#  8,
#  0,
#  2,
#  9,
#  8,
#  0,
#  0,
#  8,
#  9,
#  9,
#  4,
#  0,
#  1,
#  0,
#  8,
#  2,
#  8,
#  0,
#  4,
#  0,
#  0,
#  1,
#  0,
#  2,
#  9,
#  8,
#  0,
#  6,
#  0,
#  8,
#  8,
#  1,
#  8,
#  2,
#  7,
#  7,
#  6,
#  8,
#  1,
#  0,
#  9,
#  9,
#  0,
#  2,
#  9,
#  1,
#  9,
#  9,
#  4,
#  0,
#  4,
#  8,
#  0,
#  5,
#  8,
#  1,
#  8,
#  0,
#  1,
#  7,
#  0,
#  0,
#  6,
#  0,
#  4,
#  0,
#  0,
#  0,
#  2,
#  8,
#  1,
#  1,
#  0,
#  1,
#  5,
#  0,
#  8,
#  1,
#  0,
#  0,
#  8,
#  0,
#  7,
#  1,
#  5,
#  2,
#  9,
#  5,
#  0,
#  8,
#  8,
#  8,
#  0,
#  0,
#  6,
#  5,
#  2,
#  7,
#  9,
#  6,
#  6,
#  0,
#  6,
#  5,
#  8,
#  8,
#  0,
#  0,
#  0,
#  5,
#  0,
#  0,
#  8,
#  8,
#  2,
#  0,
#  9,
#  9,
#  8,
#  8,
#  0,
#  0,
#  1,
#  4,
#  2,
#  8,
#  8,
# ...

# %%
import pandas as pd
df = pd.DataFrame({'Category':d})

# %%
df ['Index'] = df.index

# %%
df = df[['Index','Category']]

# %%
df.to_csv('C:/temp/test_res.csv',index=False)
