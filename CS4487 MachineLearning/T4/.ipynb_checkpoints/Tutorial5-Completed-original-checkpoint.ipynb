# %% [markdown]
# **Name:** \_\_\_\_\_
#
# **EID:** \_\_\_\_\_

# %% [markdown]
# # CS4487 - Tutorial 5
# ## Predicting Popularity of Online News
#
# In this tutorial you will train a regression function to predict the number of "shares" of a news article on Mashable.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import glob
import os
import csv
import string
import IPython.utils.warn as warn
random.seed(100)

# %% [markdown]
# ## Loading Data and Pre-processing
# Next we need to load the data.  Download `OnlineNewsPopularity.zip`, and unzip it in the same directory as this ipynb file.  Then run the following cell to load the data.

# %%
filename = 'OnlineNewsPopularity/OnlineNewsPopularity.csv'

# read the data
allfeatnames = []
textdata      = []
with open(filename, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        if len(allfeatnames)==0:
            allfeatnames = row
        else:
            textdata.append(row)

# put the data into a np array
dataX = empty((len(textdata), len(allfeatnames)-3))
dataY = empty(len(textdata))
for i,row in enumerate(textdata):
    # extract features (remove the first 2 features and the last feature)
    dataX[i,:] = array(map(float, row[2:-1]))
    # extract target (last entry)
    dataY[i] = float(row[-1])
    
# extract feature names
featnames = map(string.strip, allfeatnames[2:-1])

# extract a subset of data
dataX = dataX[::6]
dataY = dataY[::6]

print dataX.shape
print dataY.shape
# Out:
# (6608, 58)
# (6608,)

# %% [markdown]
# There are 58 features for each article.  Here are the feature names, and an example entry.  The actual description of the features can be found in the `OnlineNewsPopularity-features.txt` file.

# %%
print featnames

print "--- example article features---"
print dataX[0]
print "--- example article target (# of shares)"
print dataY[0]
# Out:
# ['n_tokens_title', 'n_tokens_content', 'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length', 'num_keywords', 'data_channel_is_lifestyle', 'data_channel_is_entertainment', 'data_channel_is_bus', 'data_channel_is_socmed', 'data_channel_is_tech', 'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min', 'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg', 'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00', 'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity', 'global_sentiment_polarity', 'global_rate_positive_words', 'global_rate_negative_words', 'rate_positive_words', 'rate_negative_words', 'avg_positive_polarity', 'min_positive_polarity', 'max_positive_polarity', 'avg_negative_polarity', 'min_negative_polarity', 'max_negative_polarity', 'title_subjectivity', 'title_sentiment_polarity', 'abs_title_subjectivity', 'abs_title_sentiment_polarity']
# --- example article features---
# [  1.20000000e+01   2.19000000e+02   6.63594467e-01   9.99999992e-01
#    8.15384609e-01   4.00000000e+00   2.00000000e+00   1.00000000e+00
#    0.00000000e+00   4.68036530e+00   5.00000000e+00   0.00000000e+00
#    1.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   4.96000000e+02   4.96000000e+02
#    4.96000000e+02   1.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   5.00331204e-01   3.78278930e-01   4.00046751e-02
#    4.12626477e-02   4.01225435e-02   5.21617145e-01   9.25619835e-02
#    4.56621005e-02   1.36986301e-02   7.69230769e-01   2.30769231e-01
#    3.78636364e-01   1.00000000e-01   7.00000000e-01  -3.50000000e-01
#   -6.00000000e-01  -2.00000000e-01   5.00000000e-01  -1.87500000e-01
#    0.00000000e+00   1.87500000e-01]
# --- example article target (# of shares)
# 593.0

# %% [markdown]
# Now separate the data into training and testing sets.

# %%
# randomly split data into 50% train and 50% test set
trainX, testX, trainYo, testYo = \
  cross_validation.train_test_split(dataX, dataY, 
  train_size=0.50, test_size=0.50, random_state=4487)

print trainX.shape
print testX.shape
# Out:
# (3304, 58)
# (3304, 58)

# %% [markdown]
# Finally, we normalize the input features.

# %%
# normalize feature values
# this makes comparing weights more meaningful
scaler = preprocessing.StandardScaler()  
trainXn = scaler.fit_transform(trainX)  
testXn  = scaler.transform(testX)

# %% [markdown]
# Because the target value (number of shares) has a large dynamic range, we will transform the target values through the log function.

# %%
# map targets to log-space
trainY = log10(trainYo)
testY  = log10(testYo)

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.hist(trainYo, 25);
plt.title('histogram of Y values')
plt.subplot(1,2,2)
plt.hist(trainY, 25);
plt.title("histogram of log(Y) values");

# %% [markdown]
# ## Prediction with Linear Regression
#
# First we will look at predicting the number of shares using simple linear regression models.  Use the training data to fit a linear model using Ordinary Least Squares and Ridge Regression.  Use cross-validation on the training set to select the optimal $\alpha$ parameter for ridge regression.

# %%
### INSERT YOUR CODE HERE

ols = linear_model.LinearRegression()
ols.fit(trainXn, trainY)

trainAE = mean(abs(ols.predict(trainXn) - trainY))
testAE  = mean(abs(ols.predict(testXn) - testY))

print trainAE
print testAE
# Out:
# 0.285819488045
# 182.258122607

# %%
alphas = logspace(-5,15,30)

trainAEs = empty(len(alphas))
testAEs  = empty(len(alphas))
for i,a in enumerate(alphas):
    rr = linear_model.Ridge(alpha=a)
    rr.fit(trainXn, trainY)
    
    trainAEs[i] = mean(abs(rr.predict(trainXn) - trainY))
    testAEs[i]  = mean(abs(rr.predict(testXn) - testY))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.semilogx(alphas, trainAEs)
plt.xlabel('alpha')
plt.title('train AE')
plt.grid(True)
plt.subplot(1,2,2)
plt.semilogx(alphas, testAEs)
plt.ylabel('alpha')
plt.title('test AE')
plt.grid(True)
    
rr = linear_model.RidgeCV(alphas=alphas, cv=5)
rr.fit(trainX, trainY)

print rr.alpha_

trainAE = mean(abs(rr.predict(trainXn) - trainY))
testAE  = mean(abs(rr.predict(testXn) - testY))
print trainAE
print testAE
# Out:
# 16.1026202756
# 0.412227512389
# 0.408580135622

# %% [markdown]
# Compare the two models using the _average absolute error_ (AE) between the predictions and the true values.  Below is sample code that will calculate AE for the training and test sets.

# %%
# ols is the linear regression model
trainAE = mean(abs(ols.predict(trainXn) - trainY))
testAE  = mean(abs(ols.predict(testXn) - testY))
print trainAE
print testAE
# Out:
# 0.285819488045
# 182.258122607

# %% [markdown]
# Which model has better prediction ability on the test set? Why?
# - **INSERT YOUR ANSWER HERE**
# - RR has better performance. selecting the best alpha prevents overfitting.
# - Lin has severe overfitting -- very bad performance on test set.

# %% [markdown]
# # Which features are important?
# Next we will investigate which features are the most important for the prediction.  Use LASSO with cross-validation to learn the model.

# %%
# INSERT YOUR CODE HERE
las = linear_model.LassoCV()
las.fit(trainXn, trainY)

trainAE = mean(abs(las.predict(trainXn) - trainY))
testAE  = mean(abs(las.predict(testXn) - testY))
print trainAE
print testAE
# Out:
# 0.288657840068
# 0.284887079121

# %% [markdown]
# Examine the LASSO coefficients by sorting them in descending order.

# %%
# sort coefficients from smallest to largest, then reverse it
inds = argsort(abs(las.coef_))[::-1]
# print out
print "weight : feature description"
for i in inds:
    print "% 0.3f : %s" % (las.coef_[i], featnames[i])
# Out:
# weight : feature description
#  0.094 : kw_avg_avg
# -0.042 : LDA_02
# -0.038 : kw_max_avg
# -0.034 : data_channel_is_entertainment
# -0.027 : average_token_length
#  0.025 : global_subjectivity
#  0.025 : num_hrefs
#  0.022 : kw_min_min
# -0.022 : data_channel_is_bus
#  0.022 : is_weekend
#  0.020 : LDA_00
#  0.019 : n_tokens_content
#  0.018 : data_channel_is_socmed
# -0.018 : kw_avg_min
#  0.015 : self_reference_avg_sharess
# -0.013 : max_positive_polarity
#  0.012 : title_sentiment_polarity
# -0.012 : data_channel_is_lifestyle
#  0.009 : weekday_is_sunday
# -0.008 : LDA_01
# -0.007 : avg_negative_polarity
# -0.007 : kw_avg_max
#  0.007 : n_tokens_title
#  0.006 : self_reference_max_shares
#  0.006 : num_keywords
# -0.006 : kw_min_max
# -0.005 : weekday_is_friday
#  0.005 : weekday_is_monday
#  0.004 : data_channel_is_tech
# -0.004 : weekday_is_tuesday
# -0.003 : num_self_hrefs
#  0.003 : LDA_03
# -0.002 : min_positive_polarity
# -0.002 : rate_positive_words
#  0.002 : num_imgs
#  0.002 : self_reference_min_shares
# -0.002 : max_negative_polarity
#  0.001 : weekday_is_thursday
# -0.000 : min_negative_polarity
#  0.000 : weekday_is_saturday
#  0.000 : num_videos
# -0.000 : n_non_stop_words
# -0.000 : n_unique_tokens
# -0.000 : title_subjectivity
# -0.000 : n_non_stop_unique_tokens
#  0.000 : global_rate_negative_words
# -0.000 : avg_positive_polarity
#  0.000 : rate_negative_words
# -0.000 : data_channel_is_world
# -0.000 : kw_max_min
# -0.000 : global_rate_positive_words
# -0.000 : kw_max_max
# -0.000 : global_sentiment_polarity
#  0.000 : kw_min_avg
# -0.000 : LDA_04
#  0.000 : abs_title_subjectivity
# -0.000 : weekday_is_wednesday
#  0.000 : abs_title_sentiment_polarity

# %% [markdown]
# _Which features are most important for predicting the number of shares?  For these features, which feature values (low or high values) will yield a higher number of shares?_
# - **INSERT YOUR ANSWER HERE**
#   - kw_avg_avg -- keywords that have large average number of shares
#   - LDA02 -- not related to LDA topic 2
#   - kw_max_avg -- low number of keywords with max shares?
#   - data_channel_is_entertainment -- not entertainment channel!
#   - avg_token_length -- words with smaller number of letters.

# %% [markdown]
# # Non-linear Regression
# Now use non-linear regression to try to improve the prediction accuracy.  Use cross-validation on the training set to select the parameters.  Hint: avoid using large values of $C$ with SVR.

# %%
# KRR RBF
# parameters for cross-validation
params = {'alpha': logspace(-3,3,10),
          'gamma': logspace(-6,3,15)}

# do cross-validation with grid_search module.
krr = grid_search.GridSearchCV(
    kernel_ridge.KernelRidge(kernel='rbf'),  # estimator
    params,                                  # parameters to try
    scoring='mean_squared_error',          # score function
    cv=5,                       # number of folds
    verbose=1)                               
krr.fit(trainXn, trainY)

print krr.best_score_
print krr.best_params_

trainAE = mean(abs(krr.predict(trainXn) - trainY))
testAE  = mean(abs(krr.predict(testXn) - testY))
print trainAE
print testAE
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done  50 jobs       | elapsed:   26.2s
# [Parallel(n_jobs=1)]: Done 200 jobs       | elapsed:  2.0min
# [Parallel(n_jobs=1)]: Done 450 jobs       | elapsed:  4.7min
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -0.154587244379
# {'alpha': 0.021544346900318832, 'gamma': 0.00037275937203149417}
# 0.275117633894
# 0.28082697969
# [Parallel(n_jobs=1)]: Done 750 out of 750 | elapsed:  7.9min finished

# %%
# KRR poly
# parameters for cross-validation
params = {'alpha': logspace(-3,3,10),
          'degree': [1,2,3,4,5]}

# do cross-validation with grid_search module.
krr = grid_search.GridSearchCV(
    kernel_ridge.KernelRidge(kernel='poly'),  # estimator
    params,                                  # parameters to try
    scoring='mean_squared_error',          # score function
    cv=5, verbose=1)                               # number of folds
krr.fit(trainXn, trainY)

print krr.best_score_
print krr.best_params_

trainAE = mean(abs(krr.predict(trainXn) - trainY))
testAE  = mean(abs(krr.predict(testXn) - testY))
print trainAE
print testAE
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  50 jobs       | elapsed:   30.2s
# [Parallel(n_jobs=1)]: Done 200 jobs       | elapsed:  2.0min
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:  2.5min finished
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# -0.155257153553
# {'alpha': 10.0, 'degree': 2}
# 0.268831060682
# 0.27956156164

# %%
# LASSO - poly features
polyfeats = preprocessing.PolynomialFeatures(degree=2)
trainXnf  = polyfeats.fit_transform(trainXn)
testXnf   = polyfeats.transform(testXn) 

las = linear_model.LassoCV(max_iter=2000)
las.fit(trainXnf, trainY)

trainAE = mean(abs(las.predict(trainXnf) - trainY))
testAE  = mean(abs(las.predict(testXnf) - testY))
print trainAE
print testAE
# Out:
# 0.286457000479
# 0.286308695669

# %%
# sort coefficients from smallest to largest, then reverse it
inds = argsort(abs(las.coef_))[::-1]
print len(polyfeats.powers_)
# print out
print "weight : feature description"
for i in inds:
    if abs(las.coef_[i])>1e-3:
        # get active features and powers
        pows = where(polyfeats.powers_[i])[0]
        fstr = ""
        for p in pows:
            fstr += featnames[p] + "(" + str(polyfeats.powers_[i][p]) + ") "
        print "% 0.3f : %s" % (las.coef_[i], fstr)
# Out:
# 1770
# weight : feature description
#  0.087 : kw_avg_avg(1)
#  0.017 : kw_min_avg(2)
# -0.014 : data_channel_is_entertainment(2)
# -0.012 : LDA_02(2)
#  0.009 : kw_min_min(2)
#  0.009 : kw_max_avg(1) LDA_00(1)
#  0.008 : data_channel_is_socmed(1) LDA_00(1)
#  0.008 : weekday_is_sunday(2)
#  0.007 : n_tokens_content(2)
# -0.007 : data_channel_is_world(1) rate_negative_words(1)
# -0.007 : data_channel_is_world(1) LDA_02(1)
#  0.006 : global_subjectivity(1)
# -0.006 : n_tokens_content(1) num_imgs(1)
# -0.006 : data_channel_is_lifestyle(1) max_positive_polarity(1)
#  0.006 : data_channel_is_tech(2)
#  0.005 : weekday_is_thursday(1) title_sentiment_polarity(1)
#  0.005 : num_keywords(1) kw_avg_max(1)
#  0.005 : num_videos(1) data_channel_is_bus(1)
# -0.005 : weekday_is_monday(1) title_sentiment_polarity(1)
# -0.005 : n_tokens_title(1) n_tokens_content(1)
# -0.005 : kw_max_max(1) title_sentiment_polarity(1)
#  0.005 : num_hrefs(2)
#  0.005 : data_channel_is_socmed(2)
#  0.004 : title_sentiment_polarity(1) abs_title_sentiment_polarity(1)
#  0.004 : weekday_is_saturday(2)
#  0.004 : n_unique_tokens(1) rate_negative_words(1)
#  0.003 : LDA_00(1) global_rate_positive_words(1)
# -0.003 : n_tokens_title(1) n_non_stop_words(1)
# -0.003 : num_imgs(1) data_channel_is_socmed(1)
#  0.003 : n_tokens_content(1) num_hrefs(1)
#  0.002 : LDA_00(2)
# -0.002 : kw_max_avg(2)
#  0.002 : kw_avg_avg(1) LDA_00(1)
# -0.002 : weekday_is_monday(1) global_rate_negative_words(1)
# -0.002 : kw_max_avg(1) kw_avg_avg(1)
# -0.002 : num_self_hrefs(2)
#  0.001 : kw_min_avg(1) weekday_is_monday(1)
# -0.001 : data_channel_is_lifestyle(2)
#  0.001 : LDA_03(1) rate_negative_words(1)
# -0.001 : LDA_03(1) global_rate_positive_words(1)
#  0.001 : weekday_is_friday(1) max_positive_polarity(1)
# -0.001 : data_channel_is_lifestyle(1) avg_positive_polarity(1)
#  0.001 : weekday_is_monday(2)

# %%
# parameters for cross-validation
params = {'C':     logspace(-3,0,5),
          'degree': [1,2],
          'epsilon': logspace(-2,2,5)}

# do cross-validation with grid_search module.
svr = grid_search.GridSearchCV(
    svm.SVR(kernel='poly'),  # estimator
    params,                                  # parameters to try
    scoring='mean_squared_error',          # score function
    cv=5, 
    verbose=1)             
svr.fit(trainXn, trainY)

print svr.best_score_
print svr.best_params_

trainAE = mean(abs(svr.predict(trainXn) - trainY))
testAE  = mean(abs(svr.predict(testXn) - testY))
print trainAE
print testAE
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  50 jobs       | elapsed:   15.5s
# [Parallel(n_jobs=1)]: Done 200 jobs       | elapsed:   59.3s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:  1.4min finished
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# -0.164113400682
# {'epsilon': 0.10000000000000001, 'C': 0.031622776601683791, 'degree': 1}
# 0.281246378422
# 0.274920172675

# %% [markdown]
# _Which regression method performs the best? Why do you think so?_
# - **INSERT YOUR ANSWER HERE**
