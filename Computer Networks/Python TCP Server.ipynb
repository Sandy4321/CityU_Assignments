# %% [markdown]
# ## `TASK LIST`
# ```
# [ ] Interface
#
# [✓] Initialize the TCP socket
#
# [✓] “Server” side: wait for connection requests
#       [✓] Bind   – IP and port
#       [✓] Listen – mark a socket as accepting connections
#       [ ] Accept – a connection on a socket
#
# [ ] “Client” side: initiate the connection request
#       [ ] Input    – the remote IP and port
#       [ ] Initiate – a connection on a socket
#
# [ ] Send or receive the text to or from the peer
# [ ] Try it on your own computer
# ```

# %% [markdown]
# ### `Useful Functions`
#
# #### `Terminal`
# library `colorama`
#
# #### `Socket`
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### `Our Libraries`
# 1. python `socket` library

# %%
from socket import *

# %% [markdown]
# #### `Get My Own IP`

# %%
gethostbyname(gethostname())
# Out:
# '172.28.0.2'

# %% [markdown]
# #### `Creating Interface`
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ### `Initialize the TCP socket`
# _HOW?_
# 1. I search google : [https://docs.python.org/3.4/howto/sockets.html]
# 2. from Theresa Sources :

# %%
from socket import *

serverPort = 12000
serverSocket = socket(AF_INET,SOCK_STREAM) # this line is the same as the client

# %% [markdown]
# ### `Server Side`

# %%
serverSocket.bind(('',serverPort)) 
serverSocket.listen(1) 
print 'The server is ready to receive' 
while 1:
  connectionSocket, addr = serverSocket.accept() 
  sentence = connectionSocket.recv(1024) 
  capitalizedSentence = sentence.upper() 
  print sentence
  connectionSocket.send(capitalizedSentence) 
  connectionSocket.close()
# Out:
# The server is ready to receive
# abc
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-2-c6737517e80a> in <module>()
#       7 print 'The server is ready to receive'
#       8 while 1:
# ----> 9   connectionSocket, addr = serverSocket.accept()
#      10   sentence = connectionSocket.recv(1024)
#      11   capitalizedSentence = sentence.upper()
#
# /usr/lib/python2.7/socket.pyc in accept(self)
#     204
#     205     def accept(self):
# --> 206         sock, addr = self._sock.accept()
#     207         return _socketobject(_sock=sock), addr
#     208     accept.__doc__ = _realsocket.accept.__doc__
#
# KeyboardInterrupt:

# %% [markdown]
# ```
#   * quick tips for inserting image.
#   use <img src="URL"/> to insert
#   replace URL with https://www.base64-image.de/
#   Base64 bit image
# ```
